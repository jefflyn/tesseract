# %%
import tushare as ts
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 参数说明：
# code：股票代码，即6位数字代码，或者指数代码（sh=上证指数 sz=深圳成指 hs300=沪深300指数 sz50=上证50 zxb=中小板 cyb=创业板）
# start：开始日期，格式YYYY-MM-DD
# end：结束日期，格式YYYY-MM-DD
# ktype：数据类型，D=日k线 W=周 M=月 5=5分钟 15=15分钟 30=30分钟 60=60分钟，默认为D
# retry_count：当网络异常后重试次数，默认为3
# pause:重试时停顿秒数，默认为0
#
# 返回值说明：
# date：日期
# open：开盘价
# high：最高价
# close：收盘价
# low：最低价
# volume：成交量
# price_change：价格变动
# p_change：涨跌幅
# ma5：5日均价
# ma10：10日均价
# ma20:20日均价
# v_ma5:5日均量
# v_ma10:10日均量
# v_ma20:20日均量
# turnover:换手率[注：指数无此项]

# %%
#获取历史3年的日线数据
df = ts.get_hist_data('881115').sort_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a74db4927999> in <module>()
#       1 #获取历史3年的日线数据
# ----> 2 df = ts.get_hist_data('881115').sort_index()
#
# AttributeError: 'NoneType' object has no attribute 'sort_index'

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize=(15,5))
df['close'].plot()

# %%
df = ts.get_hist_data('000023',ktype='M').sort_index()

# %%
plt.figure(figsize=(20,5))
df['close'].plot()

# %%
df = ts.get_stock_basics()
date = df.ix['600848']['timeToMarket'] #上市日期YYYYMMDD
